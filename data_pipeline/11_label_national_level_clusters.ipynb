# %%
# 10_label_clusters.ipynb
#
# For each cluster produced by 8_cluster_national_level.ipynb, calls the OpenAI Chat API
# to generate a short title and 2-3 sentence description per cluster,
# then saves enriched results to data/8_cluster_national_level/<name>_described.csv.
#
# Uses group-level baselines and categorical distributions from step 9
# so the LLM can describe what is *distinctive* about each cluster
# compared to the broader employment group in that LA.
#
# All clusters for a single LA are sent in ONE API call.
#
# Requires OPENAI_API_KEY in environment or .env file.

import sys, os, time, json, shutil
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from pathlib import Path
from tqdm import tqdm

import importlib
import data_pipeline.config_paths as _cp
importlib.reload(_cp)
from data_pipeline.config_paths     import DATA_FOLDER, USE_FOUR_LA_SUBSET, FOUR_LA_CODES
import data_pipeline.config_variables as _cv
import data_pipeline.config_cluster   as _cc
_cv.reload_config_variables()
importlib.reload(_cc)

from data_pipeline.config_variables import VARIABLE_MAP
from data_pipeline.config_cluster   import WAVE, CLUSTER_VARS
from openai import OpenAI

# ── Load .env if present ──────────────────────────────────────────────────────
try:
    from dotenv import load_dotenv
    load_dotenv(Path('..') / '.env', override=False)
    print("Loaded .env")
except ImportError:
    pass

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY", "")
if not OPENAI_API_KEY:
    raise EnvironmentError(
        "OPENAI_API_KEY not set. Export it in your shell or add it to .env:\n"
        "  export OPENAI_API_KEY=sk-..."
    )

# ── Config ────────────────────────────────────────────────────────────────────
MODEL          = "gpt-4.1-mini"   # 32 768 output-token limit; cheap & fast
MAX_OUT_TOKENS = 32_000           # hard cap, safely under the model limit
CLUSTER_CSV = Path(f"../{DATA_FOLDER}/8_cluster_national_level/LA_london_national_clusters.csv")
OUTPUT_CSV  = CLUSTER_CSV.parent / (CLUSTER_CSV.stem + "_described.csv")
BASELINES_CSV     = Path(f"../{DATA_FOLDER}/9_group_averages/national_group_baselines.csv")
DISTRIBUTIONS_CSV = Path(f"../{DATA_FOLDER}/9_group_averages/national_group_distributions.csv")
MAX_RETRIES = 3
RETRY_DELAY = 5

# Same geography scope as 7_cluster_local_level / 9_group_averages (config_paths)
UNIT_FILTER = list(FOUR_LA_CODES) if USE_FOUR_LA_SUBSET else "london"

client = OpenAI(api_key=OPENAI_API_KEY)
print(f"Model:       {MODEL}")
print(f"Cluster CSV: {CLUSTER_CSV}")
print(f"Output CSV:  {OUTPUT_CSV}")

# ── Load CSVs ─────────────────────────────────────────────────────────────────
df = pd.read_csv(CLUSTER_CSV)
if UNIT_FILTER is None:
    pass
elif UNIT_FILTER == "london":
    df = df[df["unit_id"].astype(str).str.startswith("E09")]
elif isinstance(UNIT_FILTER, list):
    df = df[df["unit_id"].isin(set(UNIT_FILTER))]
else:
    raise ValueError("UNIT_FILTER must be None, 'london', or a list of LA codes")
if df.empty:
    raise ValueError(
        "No cluster rows after UNIT_FILTER — check CLUSTER_CSV matches config_paths "
        "(re-run 8_cluster_national_level with the same USE_FOUR_LA_SUBSET)."
    )
META_COLS = {'tribe_label', 'size', 'unit_id', 'la_name', 'cluster_level', 'group'}
print(f"Loaded {len(df)} cluster rows across {df['unit_id'].nunique()} units [USE_FOUR_LA_SUBSET={USE_FOUR_LA_SUBSET}]")

# Group baselines (from step 9)
df_baselines = pd.read_csv(BASELINES_CSV) if BASELINES_CSV.exists() else pd.DataFrame()
df_dist      = pd.read_csv(DISTRIBUTIONS_CSV) if DISTRIBUTIONS_CSV.exists() else pd.DataFrame()
_uids = set(df["unit_id"].unique())
if not df_baselines.empty:
    df_baselines = df_baselines[df_baselines["unit_id"].isin(_uids)]
if not df_dist.empty:
    df_dist = df_dist[df_dist["unit_id"].isin(_uids)]
if not df_baselines.empty:
    print(f"Loaded {len(df_baselines)} group baselines from step 9")
if not df_dist.empty:
    print(f"Loaded {len(df_dist)} distribution rows from step 9")

# ── Prompts (clustering vars from config_cluster; labels from VARIABLE_MAP) ───
_CLUSTERING_LABELS = ", ".join(VARIABLE_MAP[c] for c in CLUSTER_VARS)

SYSTEM_PROMPT = f"""You are a social researcher specialising in UK population demographics.
You will be given the statistical profiles of several population clusters from a single
Local Authority — spanning multiple employment groups (Employed, Retired, Student, etc.) —
derived from the UK Household Longitudinal Study (UKHLS).

You will first see a TOTAL POPULATION BASELINE showing the averages and categorical
breakdowns across ALL people in the LA, regardless of employment group.
Then, for each employment group, you will see a GROUP BASELINE showing the same stats
for that group only. Each cluster's stats follow.
Your job is to identify what makes each cluster distinctive compared to the total
population, its group baseline, and the other clusters.

**Clustering variables** (k-means used ONLY these):
{_CLUSTERING_LABELS}

**Title rules**
- Exactly 3–5 words, vivid and memorable.
- The title must ONLY allude to the clustering variables above.

**Description rules**
The "description" must be a single paragraph explaining what defines this cluster.
Focus on the clustering variables ({_CLUSTERING_LABELS}). Say what distinguishes this
cluster from the total population baseline, its group baseline, and the other clusters.

Respond with a JSON object with a single key "clusters" whose value is an array.
Each array element corresponds to one input cluster and must contain exactly:
  "tribe_label"  — copied verbatim from the input (used to match results back)
  "title"        — per the title rules above
  "description"  — per the description rules above

Respond with valid JSON only — no markdown code fences, no explanation outside the JSON.
Escape any line breaks inside JSON string values as \n."""

print("System prompt OK")


def _format_val(val):
    """Format a value for prompt display."""
    if pd.isna(val):
        return None
    if isinstance(val, float) and val == int(val):
        return str(int(val))
    if isinstance(val, float):
        return f"{val:.1f}"
    return str(val)


def _build_baseline_block(unit_id: str, group: str) -> list[str]:
    """Build the GROUP BASELINE text block for one (unit_id, group)."""
    lines = []
    if df_baselines.empty:
        return lines

    bl = df_baselines[(df_baselines['unit_id'] == unit_id) & (df_baselines['group'] == group)]
    if bl.empty:
        return lines

    bl_row = bl.iloc[0]
    lines.append(f"  === GROUP BASELINE: all {group} in this LA (n={int(bl_row['size']):,}) ===")

    # Continuous/binary stats from the baseline row
    skip = META_COLS | {'tribe_label', 'size', 'unit_id', 'la_name', 'cluster_level', 'group'}
    for col in bl_row.index:
        if col in skip:
            continue
        val = _format_val(bl_row[col])
        if val is not None:
            lines.append(f"    {col}: {val}")

    # Full categorical distributions
    if not df_dist.empty:
        dist = df_dist[(df_dist['unit_id'] == unit_id) & (df_dist['group'] == group)]
        if not dist.empty:
            for var_name, var_dist in dist.groupby('variable', sort=False):
                var_dist = var_dist.sort_values('pct', ascending=False)
                parts = [f"{r['category']}: {r['pct']}%" for _, r in var_dist.iterrows() if r['pct'] >= 1.0]
                if parts:
                    lines.append(f"    {var_name} breakdown: {' | '.join(parts)}")

    lines.append("")
    return lines


def build_la_prompt(unit_id: str, la_name: str, rows: pd.DataFrame) -> str:
    """Build a single prompt containing baselines + all clusters for one LA."""
    lines = [
        f"Local Authority: {la_name} ({unit_id})",
        f"Clusters to label: {len(rows)}",
        "",
    ]

    # Total population baseline for this LA
    lines.extend(_build_baseline_block(unit_id, "Total"))

    # Per-group baselines before the cluster details
    seen_groups = set()
    for _, row in rows.iterrows():
        group = row.get('group', 'Unknown')
        if group not in seen_groups:
            seen_groups.add(group)
            lines.extend(_build_baseline_block(unit_id, group))

    for _, row in rows.iterrows():
        lines += [
            f"--- tribe_label: {row['tribe_label']} ---",
            f"  Employment group: {row.get('group', 'Unknown')}",
            f"  Population size:  {int(row['size']):,}",
        ]
        for col in [c for c in row.index if c not in META_COLS]:
            val = _format_val(row[col])
            if val is not None:
                lines.append(f"  {col}: {val}")
        lines.append("")
    return "\n".join(lines)


# ── One API call per LA ───────────────────────────────────────────────────────
# (unit_id, tribe_label) -> {"gpt_title": ..., "gpt_description": ...}
label_map: dict[tuple, dict] = {}

la_name_col = "la_name" if "la_name" in df.columns else "unit_id"
unit_ids = df["unit_id"].unique().tolist()

_call_num = 0
for unit_id in tqdm(unit_ids, desc="Labelling LAs"):
    la_rows = df[df["unit_id"] == unit_id]
    la_name = la_rows[la_name_col].iloc[0]
    prompt  = build_la_prompt(unit_id, la_name, la_rows)

    _call_num += 1
    if _call_num == 1 or _call_num % 50 == 0:
        print(f"\n{'='*60}\n[Call #{_call_num}] Prompt for {la_name} ({unit_id}):\n{'='*60}")
        print(prompt)
        print('='*60)

    response_text = None
    for attempt in range(MAX_RETRIES):
        try:
            resp = client.chat.completions.create(
                model=MODEL,
                messages=[
                    {"role": "system", "content": SYSTEM_PROMPT},
                    {"role": "user",   "content": prompt},
                ],
                response_format={"type": "json_object"},
                temperature=0.7,
                max_tokens=min(450 * len(la_rows) + 400, MAX_OUT_TOKENS),
            )
            response_text = resp.choices[0].message.content
            break
        except Exception as e:
            wait = RETRY_DELAY * (2 ** attempt)
            print(f"\n  Error on {unit_id}: {e}  — retrying in {wait}s")
            time.sleep(wait)

    if not response_text:
        continue

    try:
        parsed = json.loads(response_text)
        # Expect {"clusters": [...]} but tolerate a bare list or other wrapper key
        items = parsed.get("clusters") or next(
            (v for v in parsed.values() if isinstance(v, list)), []
        )
        for item in items:
            key = (unit_id, item.get("tribe_label", ""))
            label_map[key] = {
                "gpt_title":       (item.get("title", "") or "").strip() or None,
                "gpt_description": (item.get("description", "") or "").strip() or None,
            }
    except (json.JSONDecodeError, AttributeError) as exc:
        print(f"\n  Parse error for {unit_id}: {exc}")

successful = sum(1 for v in label_map.values() if v["gpt_title"])
print(f"\nCompleted {len(unit_ids)} LA calls — {successful}/{len(df)} clusters labelled")

# ── Merge back and save ───────────────────────────────────────────────────────
df["gpt_title"]       = df.apply(lambda r: label_map.get((r["unit_id"], r["tribe_label"]), {}).get("gpt_title"),       axis=1)
df["gpt_description"] = df.apply(lambda r: label_map.get((r["unit_id"], r["tribe_label"]), {}).get("gpt_description"), axis=1)

df.to_csv(OUTPUT_CSV, index=False)
print(f"Saved {len(df)} rows to {OUTPUT_CSV}")
display(df[["unit_id", "group", "tribe_label", "size", "gpt_title", "gpt_description"]].head(12))

# ── Copy to api/ for deployment ───────────────────────────────────────────────
API_CLUSTERS_DIR = Path('..') / 'api' / 'data' / 'clusters'
API_CLUSTERS_DIR.mkdir(parents=True, exist_ok=True)
shutil.copy(OUTPUT_CSV, API_CLUSTERS_DIR / OUTPUT_CSV.name)
print(f'Copied {OUTPUT_CSV.name}  ->  api/data/clusters/')
# Out:
# Loaded .env
# Model:       gpt-4.1-mini
# Cluster CSV: ../data/8_cluster_national_level/LA_london_national_clusters.csv
# Output CSV:  ../data/8_cluster_national_level/LA_london_national_clusters_described.csv
# Loaded 40 cluster rows across 4 units [USE_FOUR_LA_SUBSET=True]
# Loaded 24 group baselines from step 9
# Loaded 984 distribution rows from step 9
# System prompt OK
# Labelling LAs:   0%|          | 0/4 [00:00<?, ?it/s]
# ============================================================
# [Call #1] Prompt for Hounslow (E09000018):
# ============================================================
# Local Authority: Hounslow (E09000018)
# Clusters to label: 10
#
#   === GROUP BASELINE: all Employed in this LA (n=84,192) ===
#     Age: 47.5
#     Sex (Derived): Male
#     Sex (Derived) %: 56
#     Ethnic group: White
#     Ethnic group %: 58
#     Highest qualification: 2.5
#     Employment status: Employed: 100%
#     Marital status: Married/Civil partner
#     Marital status %: 55
#     Housing tenure (Own/Rent): Owner-occupied
#     Housing tenure (Own/Rent) %: 67
#     Composition of household (LFS): Couple, 2 children
#     Composition of household (LFS) %: 17
#     Self-rated general health: Good
#     Self-rated general health %: 38
#     Sex (Derived) breakdown: Male: 55.6% | Female: 44.4%
#     Ethnic group breakdown: White: 57.6% | Pakistani / Bangladeshi: 15.4% | Indian: 14.1% | Other Asian: 3.7% | Mixed: 2.8% | African: 2.0% | Caribbean: 1.9% | Arab: 1.9%
#     Employment status breakdown: Employed: 100.0%
#     Marital status breakdown: Married/Civil partner: 54.9% | Never married: 26.1% | Living as couple: 8.1% | Divorced/dissolved civil partner: 7.5% | Widowed/surviving civil partner: 1.6% | Separated (incl. from civil partner): 1.5%
#     Housing tenure (Own/Rent) breakdown: Owner-occupied: 67.2% | Rented: 32.3%
#     Composition of household (LFS) breakdown: Couple, 2 children: 16.6% | 3+ adults (incl. couple), no children: 12.1% | 1 adult, no children: 11.7% | 3+ adults (incl. couple), 1–2 children: 11.4% | Couple, no children: 9.3% | 3+ adults (no couple), no children: 9.2% | Couple, 1 child: 8.5% | 2 adults (not a couple), no children: 5.3% | Couple, 3+ children: 5.3% | 1 adult, 1 child: 2.9% | 2 adults (not a couple), with children: 2.5% | 1 adult, 2+ children: 2.3% | 3+ adults (incl. couple), 3+ children: 2.1%
#     Self-rated general health breakdown: Good: 38.5% | Very good: 35.9% | Fair: 12.7% | Excellent: 10.8% | Poor: 2.2%
#
#   === GROUP BASELINE: all Retired in this LA (n=22,903) ===
#     Age: 77.2
#     Sex (Derived): Female
#     Sex (Derived) %: 52
#     Ethnic group: White
#     Ethnic group %: 78
#     Highest qualification: 3.8
#     Employment status: Retired: 100%
#     Marital status: Married/Civil partner
#     Marital status %: 50
#     Housing tenure (Own/Rent): Owner-occupied
#     Housing tenure (Own/Rent) %: 77
#     Composition of household (LFS): Couple, no children
#     Composition of household (LFS) %: 38
#     Self-rated general health: Good
#     Self-rated general health %: 36
#     Sex (Derived) breakdown: Female: 52.4% | Male: 47.6%
#     Ethnic group breakdown: White: 78.1% | Indian: 8.9% | Pakistani / Bangladeshi: 4.8% | Other Asian: 2.5% | Caribbean: 2.2% | Other: 1.3%
#     Employment status breakdown: Retired: 100.0%
#     Marital status breakdown: Married/Civil partner: 50.3% | Widowed/surviving civil partner: 22.1% | Divorced/dissolved civil partner: 13.0% | Never married: 10.5% | Living as couple: 2.4% | Separated (incl. from civil partner): 1.5%
#     Housing tenure (Own/Rent) breakdown: Owner-occupied: 76.8% | Rented: 22.5%
#     Composition of household (LFS) breakdown: Couple, no children: 37.7% | 1 adult, no children: 33.6% | 3+ adults (incl. couple), no children: 9.8% | 2 adults (not a couple), no children: 5.8% | 3+ adults (no couple), no children: 5.1% | 3+ adults (incl. couple), 1–2 children: 3.2% | 2 adults (not a couple), with children: 1.6% | 3+ adults (incl. couple), 3+ children: 1.0%
#     Self-rated general health breakdown: Good: 36.1% | Fair: 25.1% | Very good: 22.4% | Poor: 12.7% | Excellent: 3.7%
#
#   === GROUP BASELINE: all On leave in this LA (n=4,720) ===
#     Age: 46.9
#     Sex (Derived): Female
#     Sex (Derived) %: 93
#     Ethnic group: White
#     Ethnic group %: 43
#     Highest qualification: 3.7
#     Employment status: On leave: 100%
#     Marital status: Married/Civil partner
#     Marital status %: 67
#     Housing tenure (Own/Rent): Owner-occupied
#     Housing tenure (Own/Rent) %: 50
#     Composition of household (LFS): Couple, 2 children
#     Composition of household (LFS) %: 16
#     Self-rated general health: Good
#     Self-rated general health %: 37
#     Sex (Derived) breakdown: Female: 92.9% | Male: 7.1%
#     Ethnic group breakdown: White: 43.2% | Pakistani / Bangladeshi: 35.2% | Indian: 9.1% | African: 4.8% | Mixed: 2.6% | Other Asian: 2.4% | Arab: 1.5% | Caribbean: 1.3%
#     Employment status breakdown: On leave: 100.0%
#     Marital status breakdown: Married/Civil partner: 67.1% | Never married: 12.5% | Living as couple: 8.1% | Divorced/dissolved civil partner: 7.5% | Separated (incl. from civil partner): 2.4% | Widowed/surviving civil partner: 2.2%
#     Housing tenure (Own/Rent) breakdown: Owner-occupied: 50.1% | Rented: 49.6%
#     Composition of household (LFS) breakdown: Couple, 2 children: 16.0% | 3+ adults (incl. couple), 1–2 children: 15.5% | Couple, 3+ children: 12.1% | 1 adult, 2+ children: 11.7% | 3+ adults (incl. couple), no children: 9.5% | Couple, 1 child: 8.2% | 3+ adults (incl. couple), 3+ children: 6.9% | 1 adult, 1 child: 4.2% | 2 adults (not a couple), with children: 4.1% | 3+ adults (no couple), no children: 3.9% | Couple, no children: 3.1% | 2 adults (not a couple), no children: 1.7% | 1 adult, no children: 1.6% | 3+ adults (no couple), with children: 1.4%
#     Self-rated general health breakdown: Good: 36.9% | Very good: 27.8% | Fair: 22.1% | Poor: 6.6% | Excellent: 6.5%
#
#   === GROUP BASELINE: all Unemployed in this LA (n=8,038) ===
#     Age: 46.5
#     Sex (Derived): Female
#     Sex (Derived) %: 55
#     Ethnic group: Pakistani / Bangladeshi
#     Ethnic group %: 40
#     Highest qualification: 3.8
#     Employment status: Unemployed: 100%
#     Marital status: Never married
#     Marital status %: 44
#     Housing tenure (Own/Rent): Rented
#     Housing tenure (Own/Rent) %: 58
#     Composition of household (LFS): 3+ adults (incl. couple), no children
#     Composition of household (LFS) %: 16
#     Self-rated general health: Good
#     Self-rated general health %: 38
#     Sex (Derived) breakdown: Female: 55.2% | Male: 44.8%
#     Ethnic group breakdown: Pakistani / Bangladeshi: 40.3% | White: 31.5% | Indian: 12.7% | Caribbean: 3.7% | Arab: 3.6% | Other: 2.6% | Other Asian: 2.0% | African: 2.0% | Mixed: 1.8%
#     Employment status breakdown: Unemployed: 100.0%
#     Marital status breakdown: Never married: 43.6% | Married/Civil partner: 37.1% | Divorced/dissolved civil partner: 7.5% | Widowed/surviving civil partner: 5.1% | Living as couple: 4.2% | Separated (incl. from civil partner): 1.3% | Not provided: 1.2%
#     Housing tenure (Own/Rent) breakdown: Rented: 57.8% | Owner-occupied: 41.0%
#     Composition of household (LFS) breakdown: 3+ adults (incl. couple), no children: 16.1% | 1 adult, no children: 13.9% | 3+ adults (no couple), no children: 12.4% | 3+ adults (incl. couple), 1–2 children: 11.9% | 3+ adults (incl. couple), 3+ children: 8.3% | 2 adults (not a couple), no children: 5.8% | 2 adults (not a couple), with children: 5.5% | Couple, 2 children: 5.0% | 1 adult, 1 child: 4.8% | Couple, 1 child: 4.6% | Couple, 3+ children: 4.6% | Couple, no children: 2.5% | 1 adult, 2+ children: 2.5% | 3+ adults (no couple), with children: 2.2%
#     Self-rated general health breakdown: Good: 37.9% | Fair: 22.8% | Very good: 15.9% | Poor: 14.8% | Excellent: 8.6%
#
#   === GROUP BASELINE: all Student in this LA (n=3,142) ===
#     Age: 27
#     Sex (Derived): Female
#     Sex (Derived) %: 57
#     Ethnic group: White
#     Ethnic group %: 37
#     Highest qualification: 2.9
#     Employment status: Student / training: 100%
#     Marital status: Never married
#     Marital status %: 90
#     Housing tenure (Own/Rent): Owner-occupied
#     Housing tenure (Own/Rent) %: 68
#     Composition of household (LFS): 3+ adults (incl. couple), 1–2 children
#     Composition of household (LFS) %: 26
#     Self-rated general health: Very good
#     Self-rated general health %: 44
#     Sex (Derived) breakdown: Female: 57.4% | Male: 42.6%
#     Ethnic group breakdown: White: 37.0% | Pakistani / Bangladeshi: 31.9% | Indian: 18.3% | African: 4.9% | Other: 2.4% | Mixed: 2.3% | Other Asian: 2.1%
#     Employment status breakdown: Student / training: 100.0%
#     Marital status breakdown: Never married: 90.2% | Married/Civil partner: 8.6%
#     Housing tenure (Own/Rent) breakdown: Owner-occupied: 67.9% | Rented: 29.5% | Not provided: 2.0%
#     Composition of household (LFS) breakdown: 3+ adults (incl. couple), 1–2 children: 25.5% | 3+ adults (incl. couple), no children: 23.9% | 3+ adults (no couple), no children: 17.4% | 2 adults (not a couple), no children: 8.2% | 1 adult, 1 child: 5.8% | 2 adults (not a couple), with children: 5.8% | 3+ adults (incl. couple), 3+ children: 4.2% | 1 adult, no children: 3.8% | Couple, 3+ children: 1.8% | 3+ adults (no couple), with children: 1.5%
#     Self-rated general health breakdown: Very good: 43.7% | Good: 27.4% | Excellent: 14.4% | Fair: 9.0% | Poor: 5.4%
#
#   === GROUP BASELINE: all Inactive in this LA (n=5,857) ===
#     Age: 51
#     Sex (Derived): Female
#     Sex (Derived) %: 56
#     Ethnic group: White
#     Ethnic group %: 65
#     Highest qualification: 3.9
#     Employment status: Inactive: 100%
#     Marital status: Never married
#     Marital status %: 41
#     Housing tenure (Own/Rent): Rented
#     Housing tenure (Own/Rent) %: 60
#     Composition of household (LFS): 1 adult, no children
#     Composition of household (LFS) %: 21
#     Self-rated general health: Poor
#     Self-rated general health %: 45
#     Sex (Derived) breakdown: Female: 56.2% | Male: 43.8%
#     Ethnic group breakdown: White: 64.8% | Pakistani / Bangladeshi: 19.1% | Indian: 7.5% | Mixed: 3.5% | African: 1.8% | Other Asian: 1.7% | Caribbean: 1.2%
#     Employment status breakdown: Inactive: 100.0%
#     Marital status breakdown: Never married: 41.0% | Married/Civil partner: 30.8% | Divorced/dissolved civil partner: 14.5% | Widowed/surviving civil partner: 6.2% | Living as couple: 4.1% | Separated (incl. from civil partner): 2.7%
#     Housing tenure (Own/Rent) breakdown: Rented: 60.4% | Owner-occupied: 38.6%
#     Composition of household (LFS) breakdown: 1 adult, no children: 20.8% | 3+ adults (no couple), no children: 16.0% | 2 adults (not a couple), no children: 12.1% | 3+ adults (incl. couple), no children: 10.6% | 3+ adults (incl. couple), 1–2 children: 8.1% | 2 adults (not a couple), with children: 6.2% | Couple, no children: 6.0% | 1 adult, 2+ children: 4.8% | Couple, 2 children: 4.3% | Couple, 1 child: 4.0% | 1 adult, 1 child: 3.0% | Couple, 3+ children: 1.7% | 3+ adults (incl. couple), 3+ children: 1.6%
#     Self-rated general health breakdown: Poor: 45.0% | Fair: 26.6% | Good: 14.7% | Very good: 10.9% | Excellent: 2.8%
#
# --- tribe_label: Employed 1 ---
#   Employment group: Employed
#   Population size:  51,143
#   Age: 49.4
#   Sex (Derived): Male
#   Sex (Derived) %: 64
#   Ethnic group: White
#   Ethnic group %: 58
#   Highest qualification: 2.4
#   Employment status: Employed: 100%
#   Marital status: Married/Civil partner
#   Marital status %: 87
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 76
#   Composition of household (LFS): Couple, 2 children
#   Composition of household (LFS) %: 27
#   Self-rated general health: Good
#   Self-rated general health %: 40
#
# --- tribe_label: Retired 2 ---
#   Employment group: Retired
#   Population size:  11,923
#   Age: 76
#   Sex (Derived): Male
#   Sex (Derived) %: 60
#   Ethnic group: White
#   Ethnic group %: 78
#   Highest qualification: 3.5
#   Employment status: Retired: 100%
#   Marital status: Married/Civil partner
#   Marital status %: 95
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 89
#   Composition of household (LFS): Couple, no children
#   Composition of household (LFS) %: 72
#   Self-rated general health: Good
#   Self-rated general health %: 38
#
# --- tribe_label: Employed 2 ---
#   Employment group: Employed
#   Population size:  33,049
#   Age: 44.7
#   Sex (Derived): Female
#   Sex (Derived) %: 57
#   Ethnic group: White
#   Ethnic group %: 56
#   Highest qualification: 2.7
#   Employment status: Employed: 100%
#   Marital status: Never married
#   Marital status %: 67
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 53
#   Composition of household (LFS): 1 adult, no children
#   Composition of household (LFS) %: 29
#   Self-rated general health: Good
#   Self-rated general health %: 37
#
# --- tribe_label: Retired 1 ---
#   Employment group: Retired
#   Population size:  10,980
#   Age: 78.6
#   Sex (Derived): Female
#   Sex (Derived) %: 66
#   Ethnic group: White
#   Ethnic group %: 78
#   Highest qualification: 4.1
#   Employment status: Retired: 100%
#   Marital status: Widowed/surviving civil partner
#   Marital status %: 46
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 64
#   Composition of household (LFS): 1 adult, no children
#   Composition of household (LFS) %: 69
#   Self-rated general health: Good
#   Self-rated general health %: 34
#
# --- tribe_label: On leave ---
#   Employment group: On leave
#   Population size:  4,720
#   Age: 46.9
#   Sex (Derived): Female
#   Sex (Derived) %: 93
#   Ethnic group: White
#   Ethnic group %: 43
#   Highest qualification: 3.7
#   Employment status: On leave: 100%
#   Marital status: Married/Civil partner
#   Marital status %: 67
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 50
#   Composition of household (LFS): Couple, 2 children
#   Composition of household (LFS) %: 16
#   Self-rated general health: Good
#   Self-rated general health %: 37
#
# --- tribe_label: Unemployed 1 ---
#   Employment group: Unemployed
#   Population size:  3,504
#   Age: 38.3
#   Sex (Derived): Male
#   Sex (Derived) %: 52
#   Ethnic group: White
#   Ethnic group %: 37
#   Highest qualification: 3.5
#   Employment status: Unemployed: 100%
#   Marital status: Never married
#   Marital status %: 100
#   Housing tenure (Own/Rent): Rented
#   Housing tenure (Own/Rent) %: 55
#   Composition of household (LFS): 3+ adults (no couple), no children
#   Composition of household (LFS) %: 23
#   Self-rated general health: Good
#   Self-rated general health %: 40
#
# --- tribe_label: Student ---
#   Employment group: Student
#   Population size:  3,142
#   Age: 27
#   Sex (Derived): Female
#   Sex (Derived) %: 57
#   Ethnic group: White
#   Ethnic group %: 37
#   Highest qualification: 2.9
#   Employment status: Student / training: 100%
#   Marital status: Never married
#   Marital status %: 90
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 68
#   Composition of household (LFS): 3+ adults (incl. couple), 1–2 children
#   Composition of household (LFS) %: 26
#   Self-rated general health: Very good
#   Self-rated general health %: 44
#
# --- tribe_label: Inactive 2 ---
#   Employment group: Inactive
#   Population size:  3,765
#   Age: 50.2
#   Sex (Derived): Female
#   Sex (Derived) %: 58
#   Ethnic group: White
#   Ethnic group %: 69
#   Highest qualification: 4
#   Employment status: Inactive: 100%
#   Marital status: Never married
#   Marital status %: 64
#   Housing tenure (Own/Rent): Rented
#   Housing tenure (Own/Rent) %: 67
#   Composition of household (LFS): 1 adult, no children
#   Composition of household (LFS) %: 28
#   Self-rated general health: Poor
#   Self-rated general health %: 48
#
# --- tribe_label: Inactive 1 ---
#   Employment group: Inactive
#   Population size:  2,092
#   Age: 52.5
#   Sex (Derived): Female
#   Sex (Derived) %: 53
#   Ethnic group: White
#   Ethnic group %: 56
#   Highest qualification: 3.7
#   Employment status: Inactive: 100%
#   Marital status: Married/Civil partner
#   Marital status %: 86
#   Housing tenure (Own/Rent): Owner-occupied
#   Housing tenure (Own/Rent) %: 50
#   Composition of household (LFS): 3+ adults (incl. couple), no children
#   Composition of household (LFS) %: 22
#   Self-rated general health: Poor
#   Self-rated general health %: 39
#
# --- tribe_label: Unemployed 2 ---
#   Employment group: Unemployed
#   Population size:  4,534
#   Age: 52.9
#   Sex (Derived): Female
#   Sex (Derived) %: 61
#   Ethnic group: Pakistani / Bangladeshi
#   Ethnic group %: 44
#   Highest qualification: 4.1
#   Employment status: Unemployed: 100%
#   Marital status: Married/Civil partner
#   Marital status %: 66
#   Housing tenure (Own/Rent): Rented
#   Housing tenure (Own/Rent) %: 60
#   Composition of household (LFS): 3+ adults (incl. couple), no children
#   Composition of household (LFS) %: 21
#   Self-rated general health: Good
#   Self-rated general health %: 37
#
# ============================================================
# Labelling LAs: 100%|██████████| 4/4 [01:26<00:00, 21.61s/it]
# Completed 4 LA calls — 40/40 clusters labelled
# Saved 40 rows to ../data/8_cluster_national_level/LA_london_national_clusters_described.csv
#       unit_id       group   tribe_label   size  \
# 0   E09000018    Employed    Employed 1  51143
# 1   E09000018     Retired     Retired 2  11923
# 2   E09000018    Employed    Employed 2  33049
# 3   E09000018     Retired     Retired 1  10980
# 4   E09000018    On leave      On leave   4720
# 5   E09000018  Unemployed  Unemployed 1   3504
# 6   E09000018     Student       Student   3142
# 7   E09000018    Inactive    Inactive 2   3765
# 8   E09000018    Inactive    Inactive 1   2092
# 9   E09000018  Unemployed  Unemployed 2   4534
# 10  E09000019    Employed    Employed 1  42762
# 11  E09000019    Inactive    Inactive 1   1963
#
#                              gpt_title  \
# 0            Married White Male Owners
# 1         Married Elderly Male Couples
# 2          Single White Female Renters
# 3         Widowed Older Female Singles
# 4         Married White Female Parents
# 5      Young Single White Male Renters
# 6   Young Single White Female Students
# 7    Single Poor-Health Female Renters
# 8    Married Poor-Health Female Owners
# 9     Married Pakistani Female Renters
# 10          Older Married Male Couples
# 11   Middle-Aged Married Women Renters
#
#                                       gpt_description
# 0   This cluster consists mainly of older employed...
# 1   This retired cluster is characterized by older...
# 2   This employed cluster is younger (average age ...
# 3   This retired cluster is older (average 78.6), ...
# 4   This cluster comprises mostly females (93%) on...
# 5   This unemployed cluster is younger (age 38.3) ...
# 6   This student cluster mirrors the student basel...
# 7   This inactive cluster is middle-aged (50.2), p...
# 8   This inactive cluster is slightly older (52.5)...
# 9   This unemployed cluster is older (52.9), predo...
# 10  This cluster features older employed males (av...
# 11  This inactive cluster is characterized by midd...
# Copied LA_london_national_clusters_described.csv  ->  api/data/clusters/
